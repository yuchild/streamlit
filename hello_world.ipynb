# %%
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
# data source: https://ourworldindata.org/coronavirus-source-data
# updated daily
covid_data = pd.read_csv('./data/covid_data.csv')
covid_data.sample(5)
# Out:
#       iso_code      continent     location        date  total_cases  \
# 30481      LBR         Africa      Liberia  2020-05-05        170.0
# 2132       ARG  South America    Argentina  2020-08-28     392009.0
# 45356      LCA  North America  Saint Lucia  2020-10-31         78.0
# 34909      MUS         Africa    Mauritius  2020-03-28        102.0
# 11724      COL  South America     Colombia  2020-09-18     750471.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 30481        4.0               4.143          20.0         2.0
# 2132     11717.0            8995.143        8271.0       221.0
# 45356        0.0               3.714           NaN         0.0
# 34909        8.0              12.571           2.0         0.0
# 11724     6526.0            6911.857       23665.0         0.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 30481                0.571  ...         752.788             38.6
# 2132               220.143  ...       18933.907              0.6
# 45356                0.000  ...       12951.839              NaN
# 34909                0.143  ...       20292.745              0.5
# 11724              163.857  ...       13254.949              4.5
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 30481                272.509                 2.42             1.5
# 2132                 191.032                 5.50            16.2
# 45356                204.620                11.62             NaN
# 34909                224.644                22.02             3.2
# 11724                124.240                 7.44             4.7
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 30481          18.1                   1.188                        0.80
# 2132           27.7                     NaN                        5.00
# 45356           NaN                  87.202                        1.30
# 34909          40.7                     NaN                        3.40
# 11724          13.5                  65.386                        1.71
#
#        life_expectancy  human_development_index
# 30481            64.10                    0.435
# 2132             76.67                    0.825
# 45356            76.20                    0.747
# 34909            74.99                    0.790
# 11724            77.29                    0.747
#
# [5 rows x 50 columns]

# %%
covid_data.shape, covid_data.date.min(), covid_data.date.max()
# Out:
# ((61054, 50), '2020-01-01', '2020-12-06')

# %%
print(covid_data.continent.unique())
print()
print(covid_data.location.unique()[::5])
# Out:
# ['Asia' 'Europe' 'Africa' 'North America' 'South America' 'Oceania' nan]
#
# ['Afghanistan' 'Antigua and Barbuda' 'Azerbaijan' 'Belarus' 'Bolivia'
#  'Bulgaria' 'Canada' 'China' "Cote d'Ivoire"
#  'Democratic Republic of Congo' 'Ecuador' 'Estonia' 'Gabon' 'Greece'
#  'Guyana' 'Iceland' 'Iraq' 'Japan' 'Kuwait' 'Lesotho' 'Luxembourg'
#  'Maldives' 'Mauritius' 'Montenegro' 'Nepal' 'Nigeria' 'Panama' 'Poland'
#  'Rwanda' 'Sao Tome and Principe' 'Sierra Leone' 'Somalia' 'Sri Lanka'
#  'Switzerland' 'Thailand' 'Turkey' 'United States' 'Venezuela' 'Zambia']

# %% [markdown]
# $P(A \mid B) = \frac{P(B \mid A)P(A)}{P(B)}$
